# %%
import ISLP
from ISLP import load_data
from matplotlib.pyplot import subplots
import numpy as np
import pandas as pd
from pathlib import Path
import os
data_folder = Path(r'C:\Users\dmace\OneDrive\Desktop\learnig\code\python-playground\islp\data')
try:
   df = load_data('Auto')

   df.to_csv(data_folder / 'Auto.csv', index=False)
   print("yo mama")
except Exception as e:
   print("no mama")
# Out:
# yo mama

# %%
x = np.random.normal(size=50, loc=50, scale=5)
x
# Out:
# array([53.07877327, 48.27949729, 54.05468093, 52.12706046, 50.58738129,
#        43.75998076, 46.93323589, 49.43387445, 44.3474414 , 46.0363693 ,
#        33.63843726, 47.69676681, 49.14824867, 51.43516873, 50.31773607,
#        49.23783963, 54.56912282, 48.4589879 , 43.94065293, 48.29933787,
#        48.62221895, 34.90613677, 48.33172769, 54.45774639, 47.14121006,
#        47.51952531, 53.53413163, 54.42038182, 47.92345024, 50.1391332 ,
#        50.45305764, 51.8940465 , 42.73313449, 51.57044142, 52.81335104,
#        54.74978049, 46.01659267, 53.03053393, 59.18725258, 44.65019983,
#        60.82854522, 56.20769429, 36.01042222, 50.60827631, 50.39074809,
#        53.21922165, 47.16711358, 49.66078043, 52.46490869, 40.26814301])

# %%
rng = np.random.default_rng(1303)
print(rng.normal(scale=5, size=2))
# Out:
# [ 4.09482632 -1.07485605]

# %%
fig, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.scatter(x,y, marker='o')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
auto_path = data_folder / 'Auto.csv'
load_data('Auto').to_csv(auto_path, index=False)
Auto = pd.read_csv(auto_path)
Auto['horsepower']
np.unique(Auto['horsepower'])
print("The sum of the column is: " , str(Auto['horsepower'].sum()))
# Out:
# The sum of the column is:  40952

# %% [markdown]
# # ended half way through page 56
