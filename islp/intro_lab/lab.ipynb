# %%
import ISLP
from ISLP import load_data
from matplotlib.pyplot import subplots
import numpy as np
import pandas as pd
from pathlib import Path
import os
data_folder = Path(r'C:\Users\dmace\OneDrive\Desktop\learnig\code\python-playground\islp_env\Lib\site-packages\ISLP\data')

# %%
x = np.random.normal(size=50, loc=50, scale=5)
x
# Out:
# array([55.93329955, 51.424122  , 45.36625063, 50.51178554, 45.66238368,
#        38.76663419, 48.36647402, 51.3796725 , 47.49433363, 53.90182492,
#        47.86198571, 44.6184486 , 48.35078073, 57.42275049, 52.49965293,
#        48.31044397, 44.65780557, 50.37292267, 51.56204736, 47.81054588,
#        52.82938985, 50.9520217 , 48.42299762, 50.27820477, 43.67608554,
#        49.94650003, 50.50231265, 44.8356028 , 53.39494719, 51.68229672,
#        55.22072468, 48.14368005, 49.03043219, 50.08543379, 50.93001409,
#        48.12343244, 62.45415675, 43.781382  , 52.71375673, 49.24287799,
#        51.82727997, 48.13476352, 43.39268322, 53.66460148, 53.28115626,
#        53.03262616, 44.13614308, 47.52992325, 53.4087064 , 52.92429163])

# %%
rng = np.random.default_rng(1303)
print(rng.normal(scale=5, size=2))
# Out:
# [ 4.09482632 -1.07485605]

# %%
fig, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.scatter(x,y, marker='o')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
auto_path = data_folder / 'Auto.csv'
Auto = pd.read_csv(auto_path)
Auto['horsepower']
np.unique(Auto['horsepower'])
print("The sum of the column is: " , str(Auto['horsepower'].sum()))
# Out:
# The sum of the column is:  40952

# %% [markdown]
# # ended half way through page 56
